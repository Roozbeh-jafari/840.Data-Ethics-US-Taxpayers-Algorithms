# %%
import pandas as pd

# %% [markdown]
# # Data Clean

# %% [markdown]
# ## Audit Rates

# %%
df = pd.read_csv('https://raw.githubusercontent.com/propublica/auditData/master/data/cleaned/auditsData_2019.04.03.csv')

# %%
df
# Out:
#        fips                        name  ... audit_rate  audit_rate_trunk
# 0      1001     Autauga County, Alabama  ...   7.575917          7.575917
# 1      1003     Baldwin County, Alabama  ...   7.815388          7.815388
# 2      1005     Barbour County, Alabama  ...   9.127789          9.127789
# 3      1007        Bibb County, Alabama  ...   8.165829          8.165829
# 4      1009      Blount County, Alabama  ...   7.650335          7.650335
# ...     ...                         ...  ...        ...               ...
# 3136  56037  Sweetwater County, Wyoming  ...   6.803202          6.803202
# 3137  56039       Teton County, Wyoming  ...   7.721541          7.721541
# 3138  56041       Uinta County, Wyoming  ...   7.085775          7.085775
# 3139  56043    Washakie County, Wyoming  ...   6.948831          6.948831
# 3140  56045      Weston County, Wyoming  ...   7.244212          7.244212
#
# [3141 rows x 7 columns]

# %%
df.to_csv('audit_data.csv', index = False)

# %%
df[df['audit_rate'] != df['audit_rate_trunk']]
# Out:
#        fips                              name  ... audit_rate  audit_rate_trunk
# 67     2013    Aleutians East Borough, Alaska  ...   5.808081               6.0
# 71     2060       Bristol Bay Borough, Alaska  ...   3.271028               6.0
# 72     2068            Denali Borough, Alaska  ...   5.627706               6.0
# 89     2230      Skagway Municipality, Alaska  ...   5.901639               6.0
# 94     2282  Yakutat City and Borough, Alaska  ...   2.586207               6.0
# ...     ...                               ...  ...        ...               ...
# 2718  48393             Roberts County, Texas  ...   3.750000               6.0
# 2737  48431            Sterling County, Texas  ...   4.237288               6.0
# 2743  48443             Terrell County, Texas  ...   3.870968               6.0
# 2780  49009              Daggett County, Utah  ...   2.339181               6.0
# 2791  49031                Piute County, Utah  ...   5.339806               6.0
#
# ...

# %%
df['st_code'] = df['fips'].astype('string').str[:-3].astype('int')
df['cty_code'] = df['fips'].astype('string').str[-3:].astype('int')

# %%
df
# Out:
#        fips                        name  ... st_code  cty_code
# 0      1001     Autauga County, Alabama  ...       1         1
# 1      1003     Baldwin County, Alabama  ...       1         3
# 2      1005     Barbour County, Alabama  ...       1         5
# 3      1007        Bibb County, Alabama  ...       1         7
# 4      1009      Blount County, Alabama  ...       1         9
# ...     ...                         ...  ...     ...       ...
# 3136  56037  Sweetwater County, Wyoming  ...      56        37
# 3137  56039       Teton County, Wyoming  ...      56        39
# 3138  56041       Uinta County, Wyoming  ...      56        41
# 3139  56043    Washakie County, Wyoming  ...      56        43
# 3140  56045      Weston County, Wyoming  ...      56        45
#
# [3141 rows x 9 columns]

# %% [markdown]
# ## Demographic

# %%
dfg = pd.read_csv('cc-est2019-alldata.csv',  encoding = "ISO-8859-1")

# %%
dfg
# Out:
#         SUMLEV  STATE  COUNTY  ... HAAC_FEMALE HNAC_MALE  HNAC_FEMALE
# 0           50      1       1  ...          11        19           10
# 1           50      1       1  ...           0         2            1
# 2           50      1       1  ...           3         2            0
# 3           50      1       1  ...           1         1            1
# 4           50      1       1  ...           1         3            1
# ...        ...    ...     ...  ...         ...       ...          ...
# 716371      50     56      45  ...           0         0            0
# 716372      50     56      45  ...           0         0            0
# 716373      50     56      45  ...           0         0            0
# 716374      50     56      45  ...           0         0            0
# 716375      50     56      45  ...           0         0            0
#
# [716376 rows x 80 columns]

# %%
dfg[dfg['YEAR'] == 1.0]['TOT_POP'].sum()
# Out:
# 210404186.0

# %%
dfg[(dfg['STNAME'] == 'Utah') & (dfg['CTYNAME'] == 'Piute County')]
# Out:
#         SUMLEV  STATE  COUNTY  ... HAAC_FEMALE HNAC_MALE  HNAC_FEMALE
# 636576      50     49      31  ...           0         0            0
# 636577      50     49      31  ...           0         0            0
# 636578      50     49      31  ...           0         0            0
# 636579      50     49      31  ...           0         0            0
# 636580      50     49      31  ...           0         0            0
# ...        ...    ...     ...  ...         ...       ...          ...
# 636799      50     49      31  ...           0         0            0
# 636800      50     49      31  ...           0         0            0
# 636801      50     49      31  ...           0         0            0
# 636802      50     49      31  ...           0         0            0
# 636803      50     49      31  ...           0         0            0
#
# [228 rows x 80 columns]

# %%
len(dfg['STNAME'].unique())
# Out:
# 51

# %%
dfg1215 = dfg[dfg['YEAR'].isin([5,6,7,8])]
dfg1215
# Out:
#         SUMLEV  STATE  COUNTY  ... HAAC_FEMALE HNAC_MALE  HNAC_FEMALE
# 76          50      1       1  ...          10        21            5
# 77          50      1       1  ...           1         1            0
# 78          50      1       1  ...           2         2            0
# 79          50      1       1  ...           0         5            0
# 80          50      1       1  ...           1         2            0
# ...        ...    ...     ...  ...         ...       ...          ...
# 716295      50     56      45  ...           0         0            0
# 716296      50     56      45  ...           0         0            0
# 716297      50     56      45  ...           0         0            0
# 716298      50     56      45  ...           0         0            0
# 716299      50     56      45  ...           0         0            0
#
# [238792 rows x 80 columns]

# %%
dfg15 = dfg[(dfg['YEAR'] == 8) & (dfg['AGEGRP'] == 0)]
dfg15
# Out:
#         SUMLEV  STATE  COUNTY  ... HAAC_FEMALE HNAC_MALE  HNAC_FEMALE
# 133         50      1       1  ...          22        15           14
# 361         50      1       3  ...          44        39           25
# 589         50      1       5  ...           0        12            9
# 817         50      1       7  ...           2        18            4
# 1045        50      1       9  ...          14        25           21
# ...        ...    ...     ...  ...         ...       ...          ...
# 715369      50     56      37  ...          39        18           10
# 715597      50     56      39  ...          14        15            7
# 715825      50     56      41  ...           7         8            0
# 716053      50     56      43  ...           8         7            7
# 716281      50     56      45  ...           4         4            3
#
# [3142 rows x 80 columns]

# %%
dfg15['TOT_POP'].sum()
# Out:
# 320635163

# %%
dfg15['WP'] = dfg15['WA_MALE'] + dfg15['WA_FEMALE'] 
dfg15
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#         SUMLEV  STATE  COUNTY  ... HNAC_MALE HNAC_FEMALE      WP
# 133         50      1       1  ...        15          14   42650
# 361         50      1       3  ...        39          25  177081
# 589         50      1       5  ...        12           9   13088
# 817         50      1       7  ...        18           4   17251
# 1045        50      1       9  ...        25          21   55268
# ...        ...    ...     ...  ...       ...         ...     ...
# 715369      50     56      37  ...        18          10   42180
# ...

# %%
dfg15 = dfg15[['SUMLEV', 'STATE', 'COUNTY', 'STNAME', 'CTYNAME', 'TOT_POP', 'WP']]
dfg15
# Out:
#         SUMLEV  STATE  COUNTY   STNAME            CTYNAME  TOT_POP      WP
# 133         50      1       1  Alabama     Autauga County    54864   42650
# 361         50      1       3  Alabama     Baldwin County   202939  177081
# 589         50      1       5  Alabama     Barbour County    26283   13088
# 817         50      1       7  Alabama        Bibb County    22566   17251
# 1045        50      1       9  Alabama      Blount County    57526   55268
# ...        ...    ...     ...      ...                ...      ...     ...
# 715369      50     56      37  Wyoming  Sweetwater County    44719   42180
# 715597      50     56      39  Wyoming       Teton County    23047   22012
# 715825      50     56      41  Wyoming       Uinta County    20763   19865
# 716053      50     56      43  Wyoming    Washakie County     8278    7847
# 716281      50     56      45  Wyoming      Weston County     7208    6835
#
# [3142 rows x 7 columns]

# %%
dfg15['nwpp'] = 1 - (dfg15['WP'] / dfg15['TOT_POP'])
dfg15
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#         SUMLEV  STATE  COUNTY  ... TOT_POP      WP      nwpp
# 133         50      1       1  ...   54864   42650  0.222623
# 361         50      1       3  ...  202939  177081  0.127418
# 589         50      1       5  ...   26283   13088  0.502036
# 817         50      1       7  ...   22566   17251  0.235531
# 1045        50      1       9  ...   57526   55268  0.039252
# ...        ...    ...     ...  ...     ...     ...       ...
# 715369      50     56      37  ...   44719   42180  0.056777
# 715597      50     56      39  ...   23047   22012  0.044908
# ...

# %%
dfg15.to_csv('demographic_bycounty.csv')

# %% [markdown]
# ## Poverty

# %%
dfp = pd.read_csv('Poverty Data County Level.csv')

# %%
dfp
# Out:
#       Year  ...  90% Confidence Interval (Median Household Income in Dollars)
# 0     2015  ...                                 $55,690 to $55,860
# 1     2015  ...                                 $44,110 to $45,556
# 2     2015  ...                                 $51,459 to $61,701
# 3     2015  ...                                 $49,865 to $54,909
# 4     2015  ...                                 $28,622 to $34,244
# ...    ...  ...                                                ...
# 3189  2015  ...                                 $66,280 to $77,454
# 3190  2015  ...                                 $75,090 to $91,490
# 3191  2015  ...                                 $57,025 to $68,911
# 3192  2015  ...                                 $50,858 to $61,318
# 3193  2015  ...                                 $54,751 to $67,221
#
# [3194 rows x 44 columns]

# %%
dfp['st_code'] = dfp['County ID'].astype('string').str[:-3].astype('int')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-121-190a9f5793e8> in <module>()
# ----> 1 dfp['st_code'] = dfp['County ID'].astype('string').str[:-3].astype('int')
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5546         else:
#    5547             # else, only a single dtype is given
# -> 5548             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors,)
#    5549             return self._constructor(new_data).__finalize__(self, method="astype")
#    5550
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     602         self, dtype, copy: bool = False, errors: str = "raise"
#     603     ) -> "BlockManager":
# --> 604         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     605
# ...

# %%
dfp['cty_code'] = dfp['County ID'].astype('string').str[-3:].astype('int')

# %% [markdown]
# ## Unemployment

# %%
dfu = pd.read_csv('GeoFRED_Unemployment_Rate_by_County_Percent.csv')

# %%
dfu
# Out:
#        Series ID           Region Name  Region Code  ...  2016  2017  2018
# 0     SCABBE1URN  Abbeville County, SC        45001  ...   5.5   4.6   4.2
# 1     LAACAD0URN     Acadia Parish, LA        22001  ...   7.4   5.9   5.4
# 2     VAACCO1URN   Accomack County, VA        51001  ...   5.0   4.9   4.1
# 3     IDADAC1URN        Ada County, ID        16001  ...   3.3   2.8   2.4
# 4     OKADAI1URN      Adair County, OK        40001  ...   5.9   5.0   4.4
# ...          ...                   ...          ...  ...   ...   ...   ...
# 3131  COYUMA5URN       Yuma County, CO         8125  ...   2.1   1.6   2.0
# 3132  AZYUMA0URN       Yuma County, AZ         4027  ...  18.7  17.0  16.9
# 3133  TXZAPA5URN     Zapata County, TX        48505  ...  10.8   7.3   5.4
# 3134  TXZAVA7URN     Zavala County, TX        48507  ...  13.9  11.1   9.7
# 3135  SDZIEB7URN    Ziebach County, SD        46137  ...   4.5   5.2   5.0
#
# [3136 rows x 22 columns]

# %%
dfu['st_code'] = dfu['Region Code'].astype('string').str[:-3].astype('int')

# %%
dfu['cty_code'] = dfu['Region Code'].astype('string').str[-3:].astype('int')

# %%
dfu = dfu[['Region Name', 'Region Code', '2015', 'st_code', 'cty_code']]
dfu = dfu.rename(columns={'2015': 'unemployment rate'})

# %% [markdown]
# ## Income

# %%
dfi = pd.read_csv('acs2015_county_data.csv' )

# %%
dfi
# Out:
#       CensusId        State     County  ...  SelfEmployed  FamilyWork  Unemployment
# 0         1001      Alabama    Autauga  ...           5.5         0.0           7.6
# 1         1003      Alabama    Baldwin  ...           5.8         0.4           7.5
# 2         1005      Alabama    Barbour  ...           7.3         0.1          17.6
# 3         1007      Alabama       Bibb  ...           6.7         0.4           8.3
# 4         1009      Alabama     Blount  ...           4.2         0.4           7.7
# ...        ...          ...        ...  ...           ...         ...           ...
# 3215     72145  Puerto Rico  Vega Baja  ...           4.1         0.0          15.2
# 3216     72147  Puerto Rico    Vieques  ...          13.6         0.3          12.2
# 3217     72149  Puerto Rico   Villalba  ...          13.1         0.2          25.9
# 3218     72151  Puerto Rico    Yabucoa  ...           7.3         0.0          24.3
# ...

# %% [markdown]
# ## Tax Return

# %%
import pandas as pd

# %%
dft = pd.read_csv('tax-return-2015-8.csv', encoding = 'utf-8')
dft
# Out:
#       State FIPS code [1]  ... Overpayments refunded [12] amt
# 0                       0  ...                      350257176
# 1                       1  ...                        4845454
# 2                       1  ...                          53521
# 3                       1  ...                         184209
# 4                       1  ...                          24181
# ...                   ...  ...                            ...
# 3187                   56  ...                          50305
# 3188                   56  ...                         201951
# 3189                   56  ...                          22735
# 3190                   56  ...                           8604
# 3191                   56  ...                           6858
#
# [3192 rows x 131 columns]

# %%
dft['volunteer_preparer_percentage'] = dft['Number of volunteer prepared returns [2]'] / dft['Number of returns']

# %%
dft['paid_preparer_percentage'] = dft['Number with paid preparer\'s signature'] / dft['Number of returns']
dft['dividends_percentage'] = dft['Qualified dividends [5] num'] / dft['Number of returns']
dft['cap_gain_percentage'] =  dft['Net capital gain (less loss) in AGI num'] / dft['Number of returns']
dft['eic_percentage'] =  dft['Earned income credit [7] num'] / dft['Number of returns']

# %%
dft[dft['Number of returns'] > 10000].sort_values('dividends_percentage', ascending = False)
# Out:
#       State FIPS code [1] State  ...  paid_preparer_percentage dividends_percentage
# 1813                   34    NJ  ...                  0.618849             0.397091
# 389                    12    FL  ...                  0.491729             0.396110
# 212                     6    CA  ...                  0.644139             0.394856
# 2902                   51    VA  ...                  0.489420             0.364305
# 1817                   34    NJ  ...                  0.624011             0.363869
# ...                   ...   ...  ...                       ...                  ...
# 100                     4    AZ  ...                  0.576485             0.031733
# 204                     6    CA  ...                  0.667605             0.031206
# 1843                   35    NM  ...                  0.602795             0.030124
# 2779                   48    TX  ...                  0.665575             0.015555
# ...

# %% [markdown]
# ## Merge

# %%
dfmm = df.merge(dfi, how = 'left', left_on='fips', right_on='CensusId').dropna()
dfmm
# Out:
#        fips                        name  ... FamilyWork  Unemployment
# 0      1001     Autauga County, Alabama  ...        0.0           7.6
# 1      1003     Baldwin County, Alabama  ...        0.4           7.5
# 2      1005     Barbour County, Alabama  ...        0.1          17.6
# 3      1007        Bibb County, Alabama  ...        0.4           8.3
# 4      1009      Blount County, Alabama  ...        0.4           7.7
# ...     ...                         ...  ...        ...           ...
# 3136  56037  Sweetwater County, Wyoming  ...        0.0           5.4
# 3137  56039       Teton County, Wyoming  ...        0.0           2.6
# 3138  56041       Uinta County, Wyoming  ...        0.0           4.4
# 3139  56043    Washakie County, Wyoming  ...        0.5           6.8
# 3140  56045      Weston County, Wyoming  ...        1.3           5.2
#
# [3138 rows x 46 columns]

# %%
dfmm.to_csv('audit-demographics-merged.csv', index = False)

# %%
dftm = dft.merge(df, how = 'left',left_on = ['State FIPS code [1]', 'County FIPS code [1]'], right_on= ['st_code', 'cty_code'])
dftm
# Out:
#       State FIPS code [1] State  ...  st_code cty_code
# 0                       0    US  ...      NaN      NaN
# 1                       1    AL  ...      NaN      NaN
# 2                       1    AL  ...      1.0      1.0
# 3                       1    AL  ...      1.0      3.0
# 4                       1    AL  ...      1.0      5.0
# ...                   ...   ...  ...      ...      ...
# 3187                   56    WY  ...     56.0     37.0
# 3188                   56    WY  ...     56.0     39.0
# 3189                   56    WY  ...     56.0     41.0
# 3190                   56    WY  ...     56.0     43.0
# 3191                   56    WY  ...     56.0     45.0
#
# [3192 rows x 145 columns]

# %%
dftm.to_csv('tax-return-merged.csv', index= False)

# %% [markdown]
# # Model

# %%
from sklearn import linear_model
from sklearn.model_selection import cross_val_score

# %%
df.audit_rate.mean()
# Out:
# 7.730411024322167

# %%
df.audit_rate.std()
# Out:
# 0.9803595789832831

# %% [markdown]
# ## Predicting Audit Rates on Demographics

# %%
dfmm['Percentage_Male'] = dfmm['Men'] / (dfmm['Men'] + dfmm['Women'])
dfmm['Percentage_Citizen'] = dfmm['Citizen'] / dfmm['TotalPop'] 
dfmm
# Out:
#        fips                        name  ... Percentage_Male  Percentage_Citizen
# 0      1001     Autauga County, Alabama  ...        0.484327            0.737491
# 1      1003     Baldwin County, Alabama  ...        0.488487            0.756941
# 2      1005     Barbour County, Alabama  ...        0.538282            0.769122
# 3      1007        Bibb County, Alabama  ...        0.534109            0.773978
# 4      1009      Blount County, Alabama  ...        0.494056            0.733755
# ...     ...                         ...  ...             ...                 ...
# 3136  56037  Sweetwater County, Wyoming  ...        0.521732            0.691615
# 3137  56039       Teton County, Wyoming  ...        0.517099            0.733764
# 3138  56041       Uinta County, Wyoming  ...        0.508170            0.685953
# 3139  56043    Washakie County, Wyoming  ...        0.493333            0.725000
# 3140  56045      Weston County, Wyoming  ...        0.516639            0.780481
#
# ...

# %%
# X = dfmm.drop(columns = ['fips', 'name', 'state', 'CensusId', 'State', 'County', 'audit_rate'], axis

Xd = dfmm[['Percentage_Male', 'Hispanic', 'White', 'Black', 'Native', 'Asian', 'Pacific', 'Citizen', 'Income']]

# %%
yd = dfmm['audit_rate']
y
# Out:
# 0       7.575917
# 1       7.815388
# 2       9.127789
# 3       8.165829
# 4       7.650335
#           ...
# 3136    6.803202
# 3137    7.721541
# 3138    7.085775
# 3139    6.948831
# 3140    7.244212
# Name: audit_rate, Length: 3138, dtype: float64

# %%
import statsmodels.api as sm

mod = sm.OLS(yd, Xd)

# %%
res = mod.fit()

# %%
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:             audit_rate   R-squared (uncentered):                   0.991
# Model:                            OLS   Adj. R-squared (uncentered):              0.991
# Method:                 Least Squares   F-statistic:                          3.865e+04
# Date:                Sun, 23 May 2021   Prob (F-statistic):                        0.00
# Time:                        13:45:03   Log-Likelihood:                         -3489.6
# No. Observations:                3138   AIC:                                      6997.
# Df Residuals:                    3129   BIC:                                      7052.
# Df Model:                           9
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
lmd = linear_model.LinearRegression()
lmd.fit(Xd, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
cframe = pd.DataFrame({'var': Xd.columns, 'coef': lmd.coef_})
cframe
# Out:
#                var          coef
# 0  Percentage_Male -2.657045e+00
# 1         Hispanic -6.384905e-03
# 2            White -2.142263e-02
# 3            Black  7.452851e-03
# 4           Native -4.321854e-03
# 5            Asian  4.488736e-03
# 6          Pacific -8.816563e-02
# 7          Citizen -9.905603e-08
# 8           Income -3.193961e-05

# %%
lmd.coef_
# Out:
# array([-2.65704481e+00, -6.38490538e-03, -2.14226327e-02,  7.45285088e-03,
#        -4.32185412e-03,  4.48873586e-03, -8.81656331e-02, -9.90560322e-08,
#        -3.19396069e-05])

# %%
scoresd = cross_val_score(lmd, Xd, yd)
scoresd
# Out:
# array([0.4056122 , 0.53745573, 0.44506237, 0.41009848, 0.2254573 ])

# %%
scoresd.mean()
# Out:
# 0.4047372159623207

# %% [markdown]
# ## Predicting Audit Rates on Tax Return Characteristics

# %%
from sklearn import linear_model
from sklearn.model_selection import cross_val_score

# %% [markdown]
# ### Lasso - all tax

# %%
clf = linear_model.Lasso(alpha=0.1)

# %%
dftm.shape
# Out:
# (3192, 145)

# %%
dftm.dropna(inplace= True)
dftm.shape
# Out:
# (3138, 145)

# %%
X = dftm.iloc[:, 4:131]
y = dftm['audit_rate']

# %%
clf.fit(X,y)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1249.611761755597, tolerance: 0.30031235431795933
#   positive)
# Lasso(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=1000,
#       normalize=False, positive=False, precompute=False, random_state=None,
#       selection='cyclic', tol=0.0001, warm_start=False)

# %%
X
# Out:
#       Number of returns  ...  Overpayments refunded [12] amt
# 2                 23960  ...                           53521
# 3                 93140  ...                          184209
# 4                  9590  ...                           24181
# 5                  7960  ...                           19818
# 6                 22020  ...                           49419
# ...                 ...  ...                             ...
# 3187              20480  ...                           50305
# 3188              14310  ...                          201951
# 3189               9280  ...                           22735
# 3190               3770  ...                            8604
# 3191               3290  ...                            6858
#
# [3138 rows x 127 columns]

# %%
clf.coef_
# Out:
# array([ 1.60824138e-06, -6.06664096e-06,  1.19432905e-05,  4.43996215e-05,
#        -1.39729990e-05,  1.15333881e-06,  4.86368432e-06, -5.52967792e-05,
#        -2.36004081e-05, -6.87812823e-06,  1.49106615e-04,  5.22986333e-04,
#        -7.87784820e-06, -7.52888826e-06, -2.60225479e-08, -1.21164987e-06,
#         1.44493402e-08, -1.07327857e-06,  3.13558628e-08,  4.87480705e-06,
#         5.74120439e-07, -2.84793304e-05,  4.26396898e-07, -7.99911968e-06,
#        -1.76029382e-07, -1.66028586e-05, -4.28292890e-06,  2.06017958e-05,
#        -5.60695217e-08,  3.15425795e-05, -4.27233007e-08, -3.35598873e-05,
#        -8.75440762e-07, -4.72726927e-05,  1.64028985e-07,  1.29371621e-04,
#        -2.68496105e-05,  9.56726680e-06,  5.50649471e-05,  5.07161261e-07,
#         8.34770577e-05,  1.08565319e-07, -3.16538251e-05,  2.33399447e-06,
#         2.98775985e-05, -0.00000000e+00,  1.39501104e-04, -9.14374894e-06,
# ...

# %%
scores = cross_val_score(clf, X,y, cv = 10)
scores
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1058.6988222637096, tolerance: 0.26044713536947633
#   positive)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1108.7512562413847, tolerance: 0.26360224843524377
#   positive)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1201.896014890046, tolerance: 0.28597868553491806
#   positive)
# ...

# %%
scores.mean()
# Out:
# -0.9313337900737897

# %% [markdown]
# ### Selected ratios

# %%
dftm.dropna(inplace= True)
dftm.shape
# Out:
# (3138, 145)

# %%
X2 = dftm.iloc[: , 131:136]
X2
# Out:
#       volunteer_preparer_percentage  ...  eic_percentage
# 2                          0.021285  ...        0.218698
# 3                          0.018252  ...        0.191540
# 4                          0.003128  ...        0.350365
# 5                          0.006281  ...        0.285176
# 6                          0.006812  ...        0.224342
# ...                             ...  ...             ...
# 3187                       0.007812  ...        0.125000
# 3188                       0.026555  ...        0.079665
# 3189                       0.006466  ...        0.147629
# 3190                       0.031830  ...        0.129973
# 3191                       0.015198  ...        0.130699
#
# [3138 rows x 5 columns]

# %%
lm = linear_model.LinearRegression()

# %%
lm.fit(X2, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
scores2 = cross_val_score(lm, X2, y, cv = 5)
scores2
# Out:
# array([0.5647573 , 0.77700604, 0.44121129, 0.5817157 , 0.4457248 ])

# %%
scores2.mean()
# Out:
# 0.5620830246954607

# %%
lm.coef_
# Out:
# array([-1.81890596, -0.29763578,  1.68265975,  2.88910352, 12.25304259])

# %%
y.std()
# Out:
# 0.9784290530823941

# %%
y.mean()
# Out:
# 7.72875262173866

# %%
import seaborn as sns

sns.heatmap(X2.corr(), cmap = 'coolwarm')

# %%
X22 = X2.copy()
X22['audit_rate'] = y

import seaborn as sns

sns.heatmap(X22.corr(), cmap = 'coolwarm')

# %% [markdown]
# # EDA

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dfmm['audit_rate'].mean()
# Out:
# 7.731247105285301

# %%
sns.scatterplot(x = dfmm['Unemployment'], y = dfmm['audit_rate'])

# %%
sns.lmplot(x ='Unemployment', y = 'audit_rate', data = dfmm)

# %%
dfmm[dfmm['audit_rate'] > dfmm['audit_rate'].mean() ]['Unemployment'].plot.hist()

# %%
dfmm[dfmm['audit_rate'] < dfmm['audit_rate'].mean() ]['Unemployment'].plot.hist()

# %%
dfmm[dfmm['audit_rate'] < 6]
# Out:
#        fips  ... Percentage_Citizen
# 67     2013  ...           0.567191
# 71     2060  ...           0.747423
# 72     2068  ...           0.751456
# 89     2230  ...           0.777778
# 94     2282  ...           0.751166
# 187    6003  ...           0.764810
# 271    8053  ...           0.839817
# 275    8061  ...           0.732057
# 284    8079  ...           0.919509
# 300    8111  ...           0.877888
# 562   16025  ...           0.704373
# 566   16033  ...           0.479467
# 922   20071  ...           0.741013
# 1602  30011  ...           0.806846
# 1615  30037  ...           0.817460
# 1631  30069  ...           0.812641
# 1636  30079  ...           0.765306
# 1648  30103  ...           0.820197
# 1651  30109  ...           0.795132
# 1656  31007  ...           0.830488
# 1657  31009  ...           0.740472
# 1690  31075  ...           0.788036
# 1695  31085  ...           0.773063
# 1698  31091  ...           0.835536
# 1704  31103  ...           0.818565
# ...
